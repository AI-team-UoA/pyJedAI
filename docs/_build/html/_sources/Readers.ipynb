# %% [markdown]
# # Data Reading examples
# pyJedAI needs as input a pandas.DataFrame. In this notebook we provide some examples of data reading and transformation to DataFrame.
#
# ![reading-process.jpg](https://github.com/AI-team-UoA/pyJedAI/blob/main/documentation/reading-process.png?raw=true)

# %%
import pandas as pd

# %% [markdown]
# # CSV Reader
#
# Example Dataset: CORA

# %%
d1 = pd.read_csv("./data/cora/cora.csv", sep='|')
gt = pd.read_csv("./data/cora/cora_gt.csv", sep='|', header=None)

# %%
d1.head(1)
# Out:
#    Entity Id            address  \
# 0          0  los alamitos, ca:
# 1          1                NaN
# 2          2                NaN
#
#                                               author editor institution month  \
# 0  p. auer, n. cesa-bianchi, y. freund, and r. e....    NaN         NaN   NaN
# 1  a. blum, m. furst, m. j. kearns, and richard j...    NaN         NaN   NaN
# 2  avrim blum, merrick furst, michael kearns, and...    NaN         NaN   NaN
#
#   note              pages                     publisher  \
# 0  NaN       pp. 322-331.  ieee computer society press,
# 1  NaN  pages 24.1-24.10,                           NaN
# 2  NaN  pages 24.1-24.10,                           NaN
#
#                                                title  \
# 0  'gambling in a rigged casino: the adversarial ...
# 1  cryptographic primitives based on hard learnin...
# 2  cryptographic primitives based on hard learnin...
#
#                                                venue volume   year  \
# 0  in proc. 36th annual symposium on foundations ...    NaN  1995,
# 1                  in pre-proceedings of crypto '93,    NaN  1993.
# 2                  in pre-proceedings of crypto '93,    NaN  1993.
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN

# %% [markdown]
# # JSON Reader

# %%
d1 = pd.read_json("./data/cora/cora.json")
gt = pd.read_json("./data/cora/cora_gt.json")

# %%
d1.head(1)
# Out:
#    Entity Id            address  \
# 0          0  los alamitos, ca:
# 1          1               None
# 2          2               None
#
#                                               author editor institution month  \
# 0  p. auer, n. cesa-bianchi, y. freund, and r. e....   None        None  None
# 1  a. blum, m. furst, m. j. kearns, and richard j...   None        None  None
# 2  avrim blum, merrick furst, michael kearns, and...   None        None  None
#
#    note              pages                     publisher  \
# 0  None       pp. 322-331.  ieee computer society press,
# 1  None  pages 24.1-24.10,                          None
# 2  None  pages 24.1-24.10,                          None
#
#                                                title  \
# 0  'gambling in a rigged casino: the adversarial ...
# 1  cryptographic primitives based on hard learnin...
# 2  cryptographic primitives based on hard learnin...
#
#                                                venue volume   year  \
# 0  in proc. 36th annual symposium on foundations ...   None  1995,
# 1                  in pre-proceedings of crypto '93,   None  1993.
# 2                  in pre-proceedings of crypto '93,   None  1993.
#
#    Unnamed: 13
# 0          NaN
# 1          NaN
# 2          NaN

# %% [markdown]
# # Excel Reader

# %%
d1 = pd.read_excel("./data/cora/cora.xlsx")
gt = pd.read_excel("./data/cora/cora_gt.xlsx")

# %%
d1.head(1)
# Out:
#    Unnamed: 0  Entity Id            address  \
# 0           0          0  los alamitos, ca:
#
#                                               author editor institution month  \
# 0  p. auer, n. cesa-bianchi, y. freund, and r. e....    NaN         NaN   NaN
#
#   note         pages                     publisher  \
# 0  NaN  pp. 322-331.  ieee computer society press,
#
#                                                title  \
# 0  'gambling in a rigged casino: the adversarial ...
#
#                                                venue volume   year  \
# 0  in proc. 36th annual symposium on foundations ...    NaN  1995,
#
#    Unnamed: 13
# 0          NaN

# %% [markdown]
# # RDF/OWL Reader

# %%
import rdfpandas as rfd
import rdflib

rdfd1 = rdflib.Graph().parse('./data/rdf/restaurants/restaurant1.nt')
rdfd2 = rdflib.Graph().parse('./data/rdf/restaurants/restaurant2.nt')

def rdf_to_df(graph_parsed) -> pd.DataFrame:
    subject = []
    predicate = []
    rdfobject = []
    df = pd.DataFrame(columns=['subject', 'predicate', 'object'])
    for s, p, o in graph_parsed:
        subject.append(s)
        predicate.append(p)
        rdfobject.append(o)
    df['predicate'] = predicate
    df['subject'] = subject
    df['object'] = rdfobject

    return df
    
d1 = rdf_to_df(rdfd1)
d2 = rdf_to_df(rdfd2)

# %%
d1.head(2)
# Out:
#                                              subject  \
# 0       http://www.okkam.org/oaie/restaurant1-City16
# 1  http://www.okkam.org/oaie/restaurant1-Restaurant9
#
#                                            predicate              object
# 0  http://www.okkam.org/ontology_restaurant1.owl#...         los angeles
# 1  http://www.okkam.org/ontology_restaurant1.owl#...  grill on the alley

# %%
d2.head(2)
# Out:
#                                              subject  \
# 0   http://www.okkam.org/oaie/restaurant2-Address594
# 1  http://www.okkam.org/oaie/restaurant2-Restaura...
#
#                                            predicate  \
# 0    http://www.w3.org/1999/02/22-rdf-syntax-ns#type
# 1  http://www.okkam.org/ontology_restaurant2.owl#...
#
#                                               object
# 0  http://www.okkam.org/ontology_restaurant2.owl#...
# 1   http://www.okkam.org/oaie/restaurant2-Address627

# %% [markdown]
# # Relational DBs Reader

# %%
from sqlite3 import connect
conn = connect(':memory:')
d1.to_sql('d1', conn)
d2.to_sql('d2', conn)
gt.to_sql('gt', conn)
sql_d1 = pd.read_sql('SELECT * FROM d1', conn)
sql_d2 = pd.read_sql('SELECT * FROM d2', conn)
sql_gt = pd.read_sql('SELECT * FROM gt', conn)

# %%
sql_d1.head(1)
# Out:
#    index  Entity Id            address  \
# 0      0          0  los alamitos, ca:
#
#                                               author editor institution month  \
# 0  p. auer, n. cesa-bianchi, y. freund, and r. e....   None        None  None
#
#    note         pages                     publisher  \
# 0  None  pp. 322-331.  ieee computer society press,
#
#                                                title  \
# 0  'gambling in a rigged casino: the adversarial ...
#
#                                                venue volume   year Unnamed: 13
# 0  in proc. 36th annual symposium on foundations ...   None  1995,        None

# %% [markdown]
# ### PostgreSQL

# %%
from sqlalchemy import create_engine

POSTGRES_ADDRESS = 'db' ## INSERT YOUR DB ADDRESS
POSTGRES_PORT = '5439'
POSTGRES_USERNAME = 'username' ## CHANGE THIS TO YOUR POSTGRES USERNAME
POSTGRES_PASSWORD = 'root' ## CHANGE THIS TO YOUR POSTGRES PASSWORD
POSTGRES_DBNAME = 'database' ## CHANGE THIS TO YOUR DATABASE NAME
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.format(
    username=POSTGRES_USERNAME,
    password=POSTGRES_PASSWORD,
    ipaddress=POSTGRES_ADDRESS,
    port=POSTGRES_PORT,
    dbname=POSTGRES_DBNAME
))

# Create the connection
cnx = create_engine(postgres_str)

# %%
pd.read_sql('SELECT * FROM d1', cnx)

# %% [markdown]
# # SPARKQL Reader

# %%
from pandas import json_normalize
from SPARQLWrapper import SPARQLWrapper, JSON

sparql = SPARQLWrapper("http://dbpedia.org/sparql")
sparql.setQuery("""
        SELECT *
        WHERE
        {
          # ?athlete  rdfs:label      "Cristiano Ronaldo"@en ;
                    dbo:birthPlace  ?place .
         # ?place     a               dbo:City ;
                    rdfs:label      ?cityName .
        }
""")
sparql.setReturnFormat(JSON)
results = sparql.query().convert()
d1 = json_normalize(results["results"]["bindings"])

# %%
d1
# Out:
#    athlete.type                                  athlete.value place.type  \
# 0           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 1           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 2           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 3           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 4           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 5           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 6           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 7           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 8           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 9           uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 10          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 11          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 12          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 13          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 14          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 15          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 16          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 17          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 18          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 19          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
# 20          uri  http://dbpedia.org/resource/Cristiano_Ronaldo        uri
#
#                             place.value cityName.type cityName.xml:lang  \
# 0   http://dbpedia.org/resource/Funchal       literal                en
# 1   http://dbpedia.org/resource/Funchal       literal                ar
# 2   http://dbpedia.org/resource/Funchal       literal                ca
# 3   http://dbpedia.org/resource/Funchal       literal                cs
# 4   http://dbpedia.org/resource/Funchal       literal                el
# 5   http://dbpedia.org/resource/Funchal       literal                de
# 6   http://dbpedia.org/resource/Funchal       literal                eo
# 7   http://dbpedia.org/resource/Funchal       literal                es
# 8   http://dbpedia.org/resource/Funchal       literal                eu
# 9   http://dbpedia.org/resource/Funchal       literal                fr
# 10  http://dbpedia.org/resource/Funchal       literal                in
# 11  http://dbpedia.org/resource/Funchal       literal                it
# 12  http://dbpedia.org/resource/Funchal       literal                ja
# 13  http://dbpedia.org/resource/Funchal       literal                ko
# 14  http://dbpedia.org/resource/Funchal       literal                pl
# 15  http://dbpedia.org/resource/Funchal       literal                pt
# 16  http://dbpedia.org/resource/Funchal       literal                nl
# 17  http://dbpedia.org/resource/Funchal       literal                ru
# 18  http://dbpedia.org/resource/Funchal       literal                sv
# 19  http://dbpedia.org/resource/Funchal       literal                uk
# 20  http://dbpedia.org/resource/Funchal       literal                zh
#
#    cityName.value
# 0         Funchal
# 1          فونشال
# 2         Funchal
# 3         Funchal
# 4         Φουνσάλ
# 5         Funchal
# 6         Funchal
# 7         Funchal
# 8         Funchal
# 9         Funchal
# 10        Funchal
# 11        Funchal
# 12          フンシャル
# 13             푼샬
# 14        Funchal
# 15        Funchal
# 16        Funchal
# 17         Фуншал
# 18        Funchal
# 19         Фуншал
# 20            丰沙尔
